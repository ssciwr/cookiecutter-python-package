# %% [markdown]
# # Demo of the {{ cookiecutter|modname }} package

# %% [markdown]
# In the following we will demonstrate the {{ cookiecutter|modname }} package. It is currently capable of doing impressive things:

# %%
import {{ cookiecutter|modname }}

# %%
{{ cookiecutter|modname }}.add_one(1)

# %% [markdown]
# There you go: `1+1=2`!
